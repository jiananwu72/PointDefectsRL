# %% [markdown]
# <a href="https://colab.research.google.com/github/jiananwu72/LuFeO3Detect/blob/main/LuFeO3/LFOAtomap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pyNSID sidpy SciFiReaders nanonispy gwyfile pyTEMlib wget ipympl importlib atomap
# !pip install numpy==1.26.4

# %%
# %matplotlib widget
import atomap.api as am
import sys

if 'google.colab' in sys.modules:
    from google.colab import output
    output.enable_custom_widget_manager()
    from google.colab import drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from scipy.ndimage import zoom
import matplotlib.pyplot as plt
import numpy as np
import atomap.dummy_data as dummy_data
import hyperspy.api as hs
img_path = '/content/drive/MyDrive/Data/LFO/Picture2.png'
s = hs.load(img_path)

# %%
s_peaks = am.get_feature_separation(s, separation_range=(12, 20), show_progressbar=False)
s_peaks.plot()

# %%
A_positions = am.get_atom_positions(s, separation=9, threshold_rel=0.01, remove_too_close_atoms=False)
sublattice_A = am.Sublattice(A_positions, image=s.data, color='r')
# sublattice_A.find_nearest_neighbors()
# sublattice_A.refine_atom_positions_using_center_of_mass()
# sublattice_A.refine_atom_positions_using_2d_gaussian()
# sublattice_A.construct_zone_axes()
sublattice_A.plot()
# sublattice_A.plot_planes()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
